# %% [markdown]
# Implementing Supervised learning

# %% [markdown]
# The data:
# We'll use publicly available weather data for Seattle. Let's load that and restrict it to January temperatures.

# %%
import pandas as pd
import wget

# %%
# Downloading graphing
wget.download('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py')

# Optimizer
wget.download('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/m0b_optimizer.py')

# data
wget.download('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/seattleWeather_1948-2017.csv')
# Out:
# 'seattleWeather_1948-2017 (1).csv'

# %% [markdown]
# Loading the data

# %%
data = pd.read_csv('seattleWeather_1948-2017.csv', parse_dates=['date'])


data.head()
# Out:
#         date  amount_of_precipitation  max_temperature  min_temperature  rain
# 0 1948-01-01                     0.47               51               42  True
# 1 1948-01-02                     0.59               45               36  True
# 2 1948-01-03                     0.42               45               35  True
# 3 1948-01-04                     0.31               45               34  True
# 4 1948-01-05                     0.17               45               32  True

# %%
# selecting only the month of january temperature
data = data[[d.month == 1 for d in data.date]].copy()

data.head()
# Out:
#         date  amount_of_precipitation  max_temperature  min_temperature  rain
# 0 1948-01-01                     0.47               51               42  True
# 1 1948-01-02                     0.59               45               36  True
# 2 1948-01-03                     0.42               45               35  True
# 3 1948-01-04                     0.31               45               34  True
# 4 1948-01-05                     0.17               45               32  True

# %% [markdown]
# Scaling the data slightly

# %%
# This block of code scales and offsets the data slightly, which helps the training process

data['years_since_1982'] = [(d.year + d.timetuple().tm_yday / 365.25) - 1982 for d in data.date]
data.head()
# Out:
#         date  amount_of_precipitation  max_temperature  min_temperature  rain  \
# 0 1948-01-01                     0.47               51               42  True
# 1 1948-01-02                     0.59               45               36  True
# 2 1948-01-03                     0.42               45               35  True
# 3 1948-01-04                     0.31               45               34  True
# 4 1948-01-05                     0.17               45               32  True
#
#    years_since_1982
# 0        -33.997262
# 1        -33.994524
# 2        -33.991786
# 3        -33.989049
# 4        -33.986311

# %% [markdown]
# Scaling and offeseting temperature

# %%
import numpy as np

data['normalised_temperature'] = (data['min_temperature'] - np.mean(data['min_temperature'])) / np.std(data['min_temperature'])

# %% [markdown]
# Graphing

# %%
import graphing

graphing.scatter_2D(data, label_x='years_since_1982', label_y='normalised_temperature', title='January Temperatures (Normalised)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Alphonse Brandon\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\Alphonse Brandon\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Alphonse Brandon\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'years since 1982=%{x}<br>normalised temperature=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'size': 3, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([-33.99726215, -33.9945243 , -33.99178645, ...,  35.07939767,
#                            35.08213552,  35.08487337]),
#               'xaxis': 'x',
#               'y': array([ 0.92298098,  0.10753602, -0.02837147, ...,  0.24344351,  0.65116599,
#                           -0.16427896]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'January Temperatures (Normalised)'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'years since 1982'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'normalised temperature'}}}
# })
